# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    mse = MSE = np.sum((y - yp) ** 2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 186.373
# The Mean absolute error is 11.103

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
# ﹕
# 4. 這組資料想解決的問題如何評估
#
# #[作業2作答]
# 來源網址﹕https://www.kaggle.com/c/google-cloud-ncaa-march-madness-2020-division-1-mens-tournament
# Kaggle競賽題目：Google Cloud & NCAA® ML Competition 2020-NCAAM
#
# 1. NCAA，一個美國大學的籃球賽事，一個孕育nba明日之星誕生的地方。在美國或是世界上大多數的國家，每年三月被稱為三月瘋，原因是在這時候我們會看見美國眾多的大學籃球好手將參加一年一度的單淘汰制的籃球錦標賽，在這樣的賽制中，我們會看見原本被寄予期待的大學籃球員以及原本默默無聞但打出讓人瘋狂的表現的黑馬，這是比賽中好看的地方也是NBA各之球隊的球探所熱切關注的重點之一，誰會成為當年度暑假各支NBA隊伍所要選秀的對象是全球各個NBA球迷所關切的。 從以上介紹可以知道，這一切關乎著上千萬乃至上千億美金的商機，即使撇開金錢不說，根據NCAA各支球隊的歷史數據, 各支球隊之間比賽的數據, 可能因為比賽場次的增加, 球員的受傷缺席程度, 或是當球隊中的各項數據表現良好時決定著這些球隊將走的多遠。因為我們預測的結果在不久的將來就將發生,所以我想這是很有趣的題目。
#
# 2. Google cloud and NCAA提供, 包括NCAA各支球隊所紀錄的歷史數據等。
#
# 3. CSV檔案,都是以excel的形式呈現所有的資料,可以用python,pandas 或numpya以array, dict, list等方式呈現數據。
#
# 4. 要解決的問題:（1）根據所提供的資料預測過去五季的冠軍機率。(2)預測2020年本季每場比賽的結果。利用LogLoss函數評估模型的好壞,如下所示: Submissions are scored on the log loss: LogLoss=−1n∑i=1n[yilog(ŷ i)+(1−yi)log(1−ŷ i)]

# %%
# [作業3]

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#Ans:(1)載客量 (2)營收 (3)淨賺(收入-成本) (4)車隊規模(有前景,才能吸引更多的司機加入,才能增加更多的載客量,才能有更大的營收與知名度)

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#Ans:(1)一座城市的潛在對手(大眾交通工具,計程車,其他自由車隊). 資料包含潛在對手的數量, 服務的客群(包含年齡層與人數), 每年或每季或每月的載客量(包含節日,假期,天氣等)
#Ans:用傳單或是問卷的方式蒐集各類型的客群及相關資料,官網獲得或觀察預估潛在對手的車隊數量.

3. 蒐集而來的資料型態為何
#Ans:一個標明各個資料標籤及資料數據的表格.

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#Ans:根據預測的模型與提升業績之間的關係,可以調整不同參數的權重觀察對業績變化的影響作為預測結果y_hat, 並且以過去相同條件的業績作為y, 在套用MSE或MAE函式進行假設的驗證.
